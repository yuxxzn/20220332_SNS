# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
import requests

print("=" * 70)
print('Google 사이트에서 PDF 파일을 검색하여 다운로드하는 크롤러')
print("=" * 70)

keyword = input('검색어 : ')
file_no = int(input('다운로드 시도할 최대 PDF 수 : '))
f_dir = input('파일이 저장될 경로를 입력 (예: c:\\data\\) : ')

query_txt = 'PDF 저장'

def clean_filename(filename):
    # 유효하지 않은 문자를 공백으로 대체
    cleaned_filename = re.sub(r'[\\/:"*?<>|]', '', filename)
    return cleaned_filename
    
# 새로운 디렉토리 생성
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

new_dir = os.path.join(f_dir, s + '-' + query_txt)
os.makedirs(new_dir, exist_ok=True)

# Selenium을 사용하여 Google 검색 실행
path = "C:\\Temp\\chromedriver_win32\\chromedriver.exe"
driver = webdriver.Chrome()

driver.get("https://www.google.com")
search_box = driver.find_element(By.NAME, "q")
search_box.send_keys(f"{keyword} filetype:pdf")
search_box.send_keys(Keys.RETURN)

# PDF 링크 추출
time.sleep(2) 
pdf_links = []

while len(pdf_links) < file_no:
    search_results = driver.find_elements(By.CSS_SELECTOR, 'a')
    
    for result in search_results:
        href = result.get_attribute('href')
        if href and href.endswith('.pdf') and href not in pdf_links:
            pdf_links.append(href)
        if len(pdf_links) >= file_no:
            break
    
    if len(pdf_links) < file_no:
        try:
            next_button = driver.find_element(By.ID, "pnnext")
            next_button.click()
            time.sleep(2) 
        except Exception as e:
            print("다음 페이지가 없습니다.")
            break
    else:
        break

driver.quit()

# PDF 파일 다운로드 및 저장
downloaded_count = 0  
for link in pdf_links:
    if downloaded_count >= file_no:  
        break
    try:
        response = requests.get(link)
        pdf_filename = os.path.basename(link)
        pdf_path = os.path.join(new_dir, pdf_filename)
        with open(pdf_path, 'wb') as pdf_file:
            pdf_file.write(response.content)
        print(f"{pdf_path} 저장 완료")
        downloaded_count += 1  
    except Exception as e:
        print(f"다운로드 실패 {link} : {e}")

print("=" * 70)
print("파일 저장 경로: %s 입니다" % new_dir)
print("=" * 70)
# Out:
# ...
# Google 사이트에서 PDF 파일을 검색하여 다운로드하는 크롤러
# ...
# 검색어 :  소프트웨어
# 다운로드 시도할 최대 PDF 수 :  5
# 파일이 저장될 경로를 입력 (예: c:\data\) :  C:\snspy\
# C:\snspy\2024-06-13-01-47-44-PDF 저장\%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4SW-%EA%B0%9C%EB%B0%9C%EB%B0%A9%EB%B2%95%EB%A1%A0_%ED%8A%B9%ED%97%88%EC%B2%AD-2014-12.pdf 저장 완료
# C:\snspy\2024-06-13-01-47-44-PDF 저장\1.pdf 저장 완료
# C:\snspy\2024-06-13-01-47-44-PDF 저장\%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4%20%EC%82%AC%EC%9A%A9%EB%B2%95.pdf 저장 완료
# C:\snspy\2024-06-13-01-47-44-PDF 저장\20230403_64.pdf 저장 완료
# C:\snspy\2024-06-13-01-47-44-PDF 저장\AISW%EA%B3%84%EC%97%B4_%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4.pdf 저장 완료
# ...
# 파일 저장 경로: C:\snspy\2024-06-13-01-47-44-PDF 저장 입니다
# ...
# 다음 페이지가 없습니다.
# C:\snspy\2024-06-13-01-02-05-PDF 저장\g43293_1503541795.pdf 저장 완료
# C:\snspy\2024-06-13-01-02-05-PDF 저장\1686811719_2053930f9494787fc80e.pdf 저장 완료
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
import requests

print("=" * 70)
print('Google 사이트에서 PDF 파일을 검색하여 다운로드하는 크롤러')
print("=" * 70)

keyword = input('검색어 : ')
file_no = int(input('다운로드 시도할 최대 PDF 수 : '))
f_dir = input('파일이 저장될 경로를 입력 (예: c:\\data\\) : ')

query_txt = 'PDF 저장'

def clean_filename(filename):
    # 유효하지 않은 문자를 공백으로 대체
    cleaned_filename = re.sub(r'[\\/:"*?<>|]', '', filename)
    return cleaned_filename
    
# 새로운 디렉토리 생성
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

new_dir = os.path.join(f_dir, s + '-' + query_txt)
os.makedirs(new_dir, exist_ok=True)

# Selenium을 사용하여 Google 검색 실행
path = "C:\\Temp\\chromedriver_win32\\chromedriver.exe"
driver = webdriver.Chrome()

driver.get("https://www.google.com")
search_box = driver.find_element(By.NAME, "q")
search_box.send_keys(f"{keyword} filetype:pdf")
search_box.send_keys(Keys.RETURN)

# PDF 링크 추출
time.sleep(2) 
pdf_links = []

while len(pdf_links) < file_no:
    search_results = driver.find_elements(By.CSS_SELECTOR, 'a')
    
    for result in search_results:
        href = result.get_attribute('href')
        if href and href.endswith('.pdf') and href not in pdf_links:
            pdf_links.append(href)
        if len(pdf_links) >= file_no:
            break
    
    if len(pdf_links) < file_no:
        try:
            next_button = driver.find_element(By.ID, "pnnext")
            next_button.click()
            time.sleep(2) 
        except Exception as e:
            print("다음 페이지가 없습니다.")
            break
    else:
        break

driver.quit()

# PDF 파일 다운로드 및 저장
downloaded_count = 0  
for link in pdf_links:
    if downloaded_count >= file_no:  
        break
    try:
        response = requests.get(link)
        pdf_filename = os.path.basename(link)
        pdf_path = os.path.join(new_dir, pdf_filename)
        with open(pdf_path, 'wb') as pdf_file:
            pdf_file.write(response.content)
        print(f"{pdf_path} 저장 완료")
        downloaded_count += 1  
    except Exception as e:
        print(f"다운로드 실패 {link} : {e}")

print("=" * 70)
print("파일 저장 경로: %s 입니다" % new_dir)
print("=" * 70)
# Out:
# ...
# Google 사이트에서 PDF 파일을 검색하여 다운로드하는 크롤러
# ...
# 검색어 :  빅데이터
# 다운로드 시도할 최대 PDF 수 :  5
# 파일이 저장될 경로를 입력 (예: c:\data\) :  C:\snspy\
# C:\snspy\2024-06-13-01-51-21-PDF 저장\g43293_1503541795.pdf 저장 완료
# 다운로드 실패 https://smart.science.go.kr/upload_data/subject/bigdata/pdf/B_E_01.pdf : HTTPSConnectionPool(host='smart.science.go.kr', port=443): Max retries exceeded with url: /upload_data/subject/bigdata/pdf/B_E_01.pdf (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:997)')))
# C:\snspy\2024-06-13-01-51-21-PDF 저장\1686811719_2053930f9494787fc80e.pdf 저장 완료
# ...
